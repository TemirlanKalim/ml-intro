# %% [markdown]
# # How to complete this assignment
# First, download [this Kaggle dataset](https://www.kaggle.com/hugomathien/soccer) and extract *sqlite* database. You may need to register at https://www.kaggle.com/ beforehand. Then complete 15 graded tasks below, the score is given in brackets. Finally submit the resulting `.ipynb` file to rs-app Auto-test.
#
# - Do not delete or rename the variables given before the inscription `#your code here`, they are needed for the correct verification.
# - Do not change the code in the last Notebook cell, it is required for the server check.
# - Your Notebook must run completely without errors to be graded! Please check everything before submission by going *Cell -> Run All*

# %% [markdown]
# ## Some important notes
# - If you need to **calculate the number of "something"** that means we expect you to assign an Integer to the given variable
# - If you need to **make a list of "something"** we expect you to assign a Python list with appropriate values to the given variable
# - If you need to find a **specifiс player, day of the week, team, etc.** we expect you to assign a String with the full name of the entity to the given variable (`player_name`, day of week full name, `team_name`, etc.)

# %%
import sqlite3
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_column', None)

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#path = "./drive/MyDrive/Colab_Notebooks/RS_ML/1_data_manipulations/database.sqlite"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Leave that code unchanged, it is required for the server check!
#db = sqlite3.connect(("./drive/MyDrive/Colab_Notebooks/RS_ML/1_data_manipulations/database.sqlite") or 'database.sqlite')
db = sqlite3.connect(os.environ.get("DB_PATH") or 'database.sqlite')

# %%
# You may load the data from SQL table directly to the Pandas dataframe as
player_data = pd.read_sql("SELECT * FROM Player;", db)

# %%
player_data.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
player_data[['height', 'weight']].head()
# Out:
#    height  weight
# 0  182.88     187
# 1  170.18     146
# 2  170.18     163
# 3  182.88     198
# 4  182.88     154

# %%
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
player_data[player_data['birthday'] == 1980].shape[0]
# Out:
# 0

# %%
player_data[pd.to_datetime(player_data['birthday']).dt.year == 1980].head(5)
# Out:
#       id  player_api_id      player_name  player_fifa_api_id  \
# 10    11          23889    Aaron Mokoena               47189
# 46    47          37280  Abdoulaye Meite               41745
# 134  135          26136  Adama Coulibaly                5440
# 193  194          41109          Adriano              152769
# 262  263          30248       Alan Smith               13739
#
#                 birthday  height  weight
# 10   1980-11-25 00:00:00  182.88     181
# 46   1980-10-06 00:00:00  185.42     181
# 134  1980-09-10 00:00:00  185.42     183
# 193  1980-01-29 00:00:00  182.88     176
# 262  1980-10-28 00:00:00  180.34     179

# %% [markdown]
# player_data[(player_data['birthday'] >= pd.to_datetime('1980-01-01')) & (player_data['birthday'] <= pd.to_datetime('1980-12-31'))].shape[0]

# %% [markdown]
# **Task 1 (0.25 point).** Calculate the number of players with a height between 180 and 190 inclusive

# %%
players_180_190 = player_data[(player_data['height'] >= 180) & (player_data['height'] <= 190)].shape[0]

# %%
players_180_190
# Out:
# 5925

# %% [markdown]
# **Task 2 (0.25 point).** Calculate the number of players born in 1980. <br>
# **Hint:** you may want to cast your 'birthday' column to DateTime type by [pandas.to_datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
players_1980 = player_data[pd.to_datetime(player_data['birthday']).dt.year == 1980].shape[0]

# %% [markdown]
# **Task 3 (0.25 point).** Make a list of the top 10 players with the highest weight sorted in descending order. If there are several players with the same weight put them in the lexicographic order by name.

# %%
highest_players = player_data.sort_values(by=['weight', 'player_name'], ascending=(False, True)).head(10)["player_name"].values.tolist()

# %%
player_data.sort_values(by=['weight', 'player_name'], ascending=(False, True)).head(10)["player_name"].values.tolist()
# Out:
# ['Kristof van Hout',
#  'Tim Wiese',
#  'Jeroen Verhoeven',
#  'Ishmael Miller',
#  'Cassio',
#  'Christopher Samba',
#  'Lars Unnerstall',
#  'Marcus Hahnemann',
#  'Abdoulaye Faye',
#  'Enoch Showunmi']

# %% [markdown]
# **Task 4 (0.5 point).** Make a list of tuples containing years along with the number of players born in that year from 1980 up to 1990. <br>
# **Structure example**: [(1980, 123), (1981, 140) ..., (1990, 83)] -> There were born 123 players in 1980, there were born 140 players in 1981 and etc.

# %%
player_data1=player_data.copy()
player_data1['birthday']=pd.to_datetime(player_data['birthday']).dt.year
player_data1.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  birthday  \
# 0   1         505942  Aaron Appindangoye              218353      1992
# 1   2         155782     Aaron Cresswell              189615      1989
# 2   3         162549         Aaron Doran              186170      1991
# 3   4          30572       Aaron Galindo              140161      1982
# 4   5          23780        Aaron Hughes               17725      1979
#
#    height  weight
# 0  182.88     187
# 1  170.18     146
# 2  170.18     163
# 3  182.88     198
# 4  182.88     154

# %%
years_born_players = list(zip(player_data1[(player_data1['birthday'] >= 1980) & (player_data1['birthday'] <= 1990)].groupby('birthday').size().index, \
                              player_data1[(player_data1['birthday'] >= 1980) & (player_data1['birthday'] <= 1990)].groupby('birthday').size()))

# %%
years_born_players
# Out:
# [(1980, 434),
#  (1981, 475),
#  (1982, 487),
#  (1983, 541),
#  (1984, 607),
#  (1985, 593),
#  (1986, 710),
#  (1987, 722),
#  (1988, 802),
#  (1989, 723),
#  (1990, 696)]

# %%
player_data[pd.to_datetime(player_data['birthday']).dt.year == 1980].shape[0]
# Out:
# 434

# %%
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
player_data1=player_data.copy()
player_data1['birthday']=pd.to_datetime(player_data['birthday']).dt.year
player_data1.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  birthday  \
# 0   1         505942  Aaron Appindangoye              218353      1992
# 1   2         155782     Aaron Cresswell              189615      1989
# 2   3         162549         Aaron Doran              186170      1991
# 3   4          30572       Aaron Galindo              140161      1982
# 4   5          23780        Aaron Hughes               17725      1979
#
#    height  weight
# 0  182.88     187
# 1  170.18     146
# 2  170.18     163
# 3  182.88     198
# 4  182.88     154

# %%
player_data[(pd.to_datetime(player_data['birthday']).dt.year >= 1980) & (pd.to_datetime(player_data['birthday']).dt.year <= 1990)]
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 1          2         155782      Aaron Cresswell              189615
# 3          4          30572        Aaron Galindo              140161
# 5          6          27316           Aaron Hunt              158138
# 7          8          30895         Aaron Lennon              152747
# 9         10         101042        Aaron Meijers              188621
# ...      ...            ...                  ...                 ...
# 11053  11069         192132   Zouhaier Dhaouadhi              195840
# 11054  11070         282473       Zouhair Feddal              205705
# 11056  11072         111182         Zsolt Laczko              164680
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 1      1989-12-15 00:00:00  170.18     146
# 3      1982-05-08 00:00:00  182.88     198
# ...

# %% [markdown]
# **Task 5 (0.5 point).** Calculate the mean and the standard deviation of the players' **height** with the name **Adriano**. <br>
# **Note:** Name is represented by the first part of `player_name`.

# %%
adriano_mean, adriano_std = player_data1[player_data1['player_name'].str.contains('Adriano') & ~player_data1['player_name'].str.contains(' Adriano')]['height'].mean()\
              , player_data1[player_data1['player_name'].str.contains('Adriano') & ~player_data1['player_name'].str.contains(' Adriano')]['height'].std()# Your code here

# %%
adriano_mean
# Out:
# 182.11800000000002

# %% [markdown]
# **Task 6 (0.75 point).** How many players were born on each day of the week? Find the day of the week with the minimum number of players born.

# %%
player_data['birthday']=pd.to_datetime(player_data['birthday'])
player_data['day_of_week'] = player_data['birthday'].dt.day_name()

# %%
player_data.groupby('day_of_week').size().sort_values().index[0]
# Out:
# 'Sunday'

# %%
dow_with_min_players_born = player_data.groupby('day_of_week').size().sort_values().index[0]# Your code here

# %% [markdown]
# **Task 7 (0.75 point).** Find a league with the most matches in total. If there are several leagues with the same amount of matches, take the first in the lexical order.

# %%
# You may load the data from SQL table directly to the Pandas dataframe as
match_data = pd.read_sql("SELECT * FROM Match;", db)
league_data = pd.read_sql("SELECT * FROM League;", db)

# %%
league_data['matches']=match_data.groupby('league_id').size().values
league_data.sort_values(by=['matches','name'], ascending=[True,False]).iloc[-1]["name"]
# Out:
# 'England Premier League'

# %%
league_most_matches = league_data.sort_values(by=['matches','name'], ascending=[True,False]).iloc[-1]["name"]# Your code here

# %% [markdown]
# **Task 8 (1.25 point).** Find a player who participated in the largest number of matches during the whole match history. Assign a `player_name` to the given variable

# %%
match_data.tail()
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 25974       1992091             10190             10191               1
# 25975       1992092              9824             10199               1
# 25976       1992093              9956             10179               2
# 25977       1992094              7896             10243               0
# 25978       1992095             10192              9931               4
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# ...

# %%
match_data.loc[:,"home_player_1":"away_player_11"].apply(pd.Series.value_counts)
# Out:
#           home_player_1  home_player_2  home_player_3  home_player_4  \
# 2625.0              NaN            NaN            NaN            NaN
# 2752.0              NaN            NaN            9.0           28.0
# 2768.0              NaN            NaN            4.0           31.0
# 2770.0              NaN            NaN            NaN            NaN
# 2790.0              NaN            NaN            NaN            NaN
# ...                 ...            ...            ...            ...
# 744907.0            NaN            1.0            NaN            NaN
# 746419.0            NaN            NaN            NaN            NaN
# 748432.0            NaN            1.0            NaN            NaN
# 750435.0            NaN            NaN            NaN            NaN
# 750584.0            NaN            NaN            NaN            NaN
#
#           home_player_5  home_player_6  home_player_7  home_player_8  \
# ...

# %%
player_data[player_data['player_api_id']==match_data.loc[:,"home_player_1":"away_player_11"].apply(pd.Series.value_counts).sum(axis=1).sort_values().index[-1]]
# Out:
#          id  player_api_id     player_name  player_fifa_api_id   birthday  \
# 9993  10009          31293  Steve Mandanda              163705 1985-03-28
#
#       height  weight day_of_week
# 9993  185.42     181    Thursday

# %%
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#         birthday  height  weight day_of_week
# 0     1992-02-29  182.88     187    Saturday
# 1     1989-12-15  170.18     146      Friday
# ...

# %%
max_matches_player = player_data[player_data['player_api_id']==match_data.loc[:,"home_player_1":"away_player_11"].apply(pd.Series.value_counts).sum(axis=1).sort_values().index[-1]].player_name.values[0] # Your code here

# %%
max_matches_player
# Out:
# 'Steve Mandanda'

# %% [markdown]
# **Task 9 (1.5 point).** List top-5 tuples of most correlated **player's characteristics** in the descending order of the absolute [Pearson's coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) value.
#
# **Note 1:** Players characteristics are all the columns in `Player_Attributes` table except `[id, player_fifa_api_id, player_api_id, date, preferred_foot, attacking_work_rate, defensive_work_rate]`). <br>
# **Note 2:** Exclude duplicated pairs from the list. E.g. ('gk_handling', 'gk_reflexes') and ('gk_reflexes', 'gk_handling') are duplicates, leave just one of them in the resulting list.
#
# **Hint:** You may use [dataframe.corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) for calculating pairwise Pearson correlation.

# %%
player_attr = pd.read_sql("SELECT * FROM Player_Attributes;", db)

# %%
player_attr.head(2)
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
#
#    finishing  heading_accuracy  short_passing  volleys  dribbling  curve  \
# 0       44.0              71.0           61.0     44.0       51.0   45.0
# 1       44.0              71.0           61.0     44.0       51.0   45.0
#
#    free_kick_accuracy  long_passing  ball_control  acceleration  sprint_speed  \
# 0                39.0          64.0          49.0          60.0          64.0
# 1                39.0          64.0          49.0          60.0          64.0
#
# ...

# %%
correl=player_attr.loc[:,"overall_rating":].corr()

# %%
res=correl.stack().tolist()
res.sort(reverse=True)
res2 = []
[res2.append(x) for x in res if x not in res2]
valuess=res2[1:6]

# %%
correl[correl.isin(valuess)].stack().drop_duplicates().sort_values(ascending=False)
# Out:
# gk_positioning   gk_reflexes        0.966711
# gk_handling      gk_reflexes        0.966326
#                  gk_positioning     0.966301
# standing_tackle  sliding_tackle     0.953104
# marking          standing_tackle    0.950134
# dtype: float64

# %%
top_correlated_features = correl[correl.isin(valuess)].stack().drop_duplicates().sort_values(ascending=False).index.values.tolist()# Your code here

# %% [markdown]
# **Task 10 (2 points).** Find top-5 most similar players to **Neymar** whose names are given. The similarity is measured as [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) between vectors of players' characteristics (described in the task above). Put their names in a vector in ascending order by Euclidean distance and sorted by `player_name` if the distance is the same<br>
# **Note 1:** There are many records for some players in the `Player_Attributes` table. You need to take the freshest data (characteristics with the most recent `date`). <br>
# **Note 2:** Use pure values of the characteristics even if you are aware of such preprocessing technics as normalization. <br>
# **Note 3:** Please avoid using any built-in methods for calculating the Euclidean distance between vectors, think about implementing your own.

# %% [markdown]
# 1)Находим айди Неймара
# 2)отнимаем от его хар-к хар-ки других игроков возводим в квадрат и суммируем
# 3)

# %%
player_attr2=player_attr.drop_duplicates(subset=['player_api_id'])

# %%
player_attr2.head()
# Out:
#     id  player_fifa_api_id  player_api_id                 date  \
# 0    1              218353         505942  2016-02-18 00:00:00
# 5    6              189615         155782  2016-04-21 00:00:00
# 38  39              186170         162549  2016-01-07 00:00:00
# 64  65              140161          30572  2016-04-21 00:00:00
# 87  88               17725          23780  2015-12-24 00:00:00
#
#     overall_rating  potential preferred_foot attacking_work_rate  \
# 0             67.0       71.0          right              medium
# 5             74.0       76.0           left                high
# 38            65.0       67.0          right              medium
# 64            69.0       69.0          right              medium
# 87            70.0       70.0          right              medium
#
#    defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0               medium      49.0       44.0              71.0           61.0
# ...

# %%
#1)Находим айди Неймара 
ney_id=player_data[player_data["player_name"]=="Neymar"].player_api_id.values[0]

# %%
player_attr3=player_attr2.loc[:, ~player_attr2.columns.isin(['id', 'player_fifa_api_id',"player_api_id","date","preferred_foot","attacking_work_rate","defensive_work_rate"])]

# %%
player_attr3
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0                 67.0       71.0      49.0       44.0              71.0
# 5                 74.0       76.0      80.0       53.0              58.0
# 38                65.0       67.0      64.0       58.0              60.0
# 64                69.0       69.0      57.0       21.0              68.0
# 87                70.0       70.0      46.0       34.0              73.0
# ...                ...        ...       ...        ...               ...
# 183924            73.0       73.0      42.0       27.0              74.0
# 183937            63.0       67.0      65.0       44.0              59.0
# 183953            68.0       73.0      64.0       38.0              71.0
# 183960            67.0       78.0      48.0       43.0              79.0
# 183968            78.0       78.0      77.0       70.0              59.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  \
# ...

# %%
ney_id_attr=player_attr3[player_attr2["player_api_id"]==ney_id]

# %%
ney_id_attr.values
# Out:
# array([[90., 94., 72., 88., 62., 78., 83., 94., 78., 79., 74., 93., 91.,
#         90., 92., 86., 84., 78., 61., 79., 45., 73., 56., 36., 89., 79.,
#         81., 21., 24., 33.,  9.,  9., 15., 15., 11.]])

# %%
ney_id_attr-player_attr3.loc[0,]
# Out:
#         overall_rating  potential  crossing  finishing  heading_accuracy  \
# 131464            23.0       23.0      23.0       44.0              -9.0
#
#         short_passing  volleys  dribbling  curve  free_kick_accuracy  \
# 131464           17.0     39.0       43.0   33.0                40.0
#
#         long_passing  ball_control  acceleration  sprint_speed  agility  \
# 131464          10.0          44.0          31.0          26.0     33.0
#
#         reactions  balance  shot_power  jumping  stamina  strength  \
# 131464       39.0     19.0        23.0      3.0     25.0     -31.0
#
#         long_shots  aggression  interceptions  positioning  vision  penalties  \
# 131464        38.0       -15.0          -34.0         44.0    25.0       33.0
#
#         marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 131464    -44.0            -45.0           -36.0        3.0         -2.0
#
#         gk_kicking  gk_positioning  gk_reflexes
# ...

# %%
player_data[player_data["player_api_id"]==505942].player_name.values[0]
# Out:
# 'Aaron Appindangoye'

# %% [markdown]
# #players=[]
# for index,x in player_attr2.iterrows():
#   if x.player_api_id==ney_id:
#     continue
#   for index2,y in x.items():
#     if type(y)!=float:
#       continue
#     print(index2,y)
#     print(ney_id_attr[index2].values[0])
#     print(y-ney_id_attr[index2].values[0])
#     break
#   break

# %%
players=[]
for index,x in player_attr2.iterrows():
  if x.player_api_id==ney_id:
    continue
  players.append([x.player_api_id,np.square(ney_id_attr.values-player_attr3.loc[index,].values).sum()])  
players_res=pd.DataFrame(players,columns=["id", "value"])

# %%
ney_top5=players_res.dropna().sort_values(by="value").head(5).id.values

# %%
neymar_similarities=[]
for x in ney_top5:
  neymar_similarities.append(player_data[player_data["player_api_id"]==x].player_name.values[0])
neymar_similarities
# Out:
# ['Paulo Dybala',
#  'Eden Hazard',
#  'Giovani dos Santos',
#  'Arjen Robben',
#  'Lionel Messi']

# %% [markdown]
# **Task 11 (1 point).** Calculate the number of home matches played by the **Borussia Dortmund** team in **Germany 1. Bundesliga** in season **2008/2009**

# %%
Ger_Id=7809
Bor_Id=9789

# %%
match_data.loc[(match_data["league_id"]==Ger_Id) & (match_data["season"]=="2008/2009") & (match_data["home_team_api_id"]==Bor_Id)].shape[0]
# Out:
# 17

# %%
borussia_bundesliga_2008_2009_matches = match_data.loc[(match_data["league_id"]==Ger_Id) & (match_data["season"]=="2008/2009") & (match_data["home_team_api_id"]==Bor_Id)].shape[0]# Your code here

# %% [markdown]
# **Task 12 (1 point).** Find a team having the most matches (both home and away!) in the **Germany 1. Bundesliga** in **2008/2009** season. Return number of matches.

# %%
match_data.loc[(match_data["league_id"]==Ger_Id) & (match_data["season"]=="2008/2009")].loc[:,"home_team_api_id":"away_team_api_id"].apply(pd.Series.value_counts).sum(axis=1).sort_values().values[0]
# Out:
# 34

# %%
team_most_matches_bundesliga_2008_2009 = int(match_data.loc[(match_data["league_id"]==Ger_Id) & (match_data["season"]=="2008/2009")].loc[:,"home_team_api_id":"away_team_api_id"].apply(pd.Series.value_counts).sum(axis=1).sort_values().values[0])# Your code here

# %% [markdown]
# **Task 13 (1 point).** Count total number of **Arsenal** matches (both home and away!) in the **2015/2016** season which they have won. <br><br>
# **Note:** Winning a game means scoring **more** goals than an opponent.

# %%
Eng_Id=1729
Ars_Id=9825

# %%
match_data.head(1)
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        492473              9987              9993               1
#
#    away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0               1             NaN             NaN             NaN
#
#    home_player_X4  home_player_X5  home_player_X6  home_player_X7  \
# 0             NaN             NaN             NaN             NaN
#
#    home_player_X8  home_player_X9  home_player_X10  home_player_X11  \
# 0             NaN             NaN              NaN              NaN
#
#    away_player_X1  away_player_X2  away_player_X3  away_player_X4  \
# 0             NaN             NaN             NaN             NaN
#
#    away_player_X5  away_player_X6  away_player_X7  away_player_X8  \
# 0             NaN             NaN             NaN             NaN
#
# ...

# %%
match_data.loc[(match_data["league_id"]==Eng_Id) & (match_data["season"]=="2015/2016") & \
               ((match_data["home_team_api_id"]==Ars_Id) & (match_data["home_team_goal"]>match_data["away_team_goal"]) | \
                (match_data["away_team_api_id"]==Ars_Id) & (match_data["home_team_goal"]<match_data["away_team_goal"])) ].shape[0]
# Out:
# 20

# %%
arsenal_won_matches_2015_2016 = match_data.loc[(match_data["league_id"]==Eng_Id) & (match_data["season"]=="2015/2016") & \
               ((match_data["home_team_api_id"]==Ars_Id) & (match_data["home_team_goal"]>match_data["away_team_goal"]) | \
                (match_data["away_team_api_id"]==Ars_Id) & (match_data["home_team_goal"]<match_data["away_team_goal"])) ].shape[0]# Your code here

# %% [markdown]
# **Task 14 (2 points).** Find a team with the highest win rate in the **2015/2016** season. Win rate means won matches / all matches. If there are several teams with the highest win rate return the first by name in lexical order

# %%
match_data2=match_data.copy()

# %%
teams_data = pd.read_sql("SELECT * FROM Team;", db)

# %%
match_data2.loc[(match_data2["home_team_goal"]>match_data2["away_team_goal"]), 'winning_team'] = match_data["home_team_api_id"]
match_data2.loc[(match_data2["home_team_goal"]<match_data2["away_team_goal"]), 'winning_team'] = match_data["away_team_api_id"]

# %%
winrate=match_data2.loc[(match_data2["season"]=="2015/2016")].loc[:,["home_team_api_id","away_team_api_id","winning_team"]].apply(pd.Series.value_counts)

# %%
winrate["Winrate"]=winrate["winning_team"]/(winrate["home_team_api_id"]*2)

# %%
teams_data[teams_data["team_api_id"]==winrate.sort_values(by="Winrate").index[-1]].team_long_name.values[0]
# Out:
# 'SL Benfica'

# %%
team_highest_winrate_2015_2016 = teams_data[teams_data["team_api_id"]==winrate.sort_values(by="Winrate").index[-1]].team_long_name.values[0]# Your code here

# %% [markdown]
# **Task 15 (2 points).** Determine the team with the maximum days' gap between matches in **England Premier League 2010/2011 season**. Return number of days in that gap. <br>
# **Note**: a *gap* means the number of days between two consecutive matches of the same team.

# %%
clear_data=match_data.loc[(match_data["league_id"]==Eng_Id) & (match_data["season"]=="2010/2011")].loc[:,['date','match_api_id','home_team_api_id','away_team_api_id']].sort_values(by=["date","match_api_id"])

# %%
clear_data
# Out:
#                      date  match_api_id  home_team_api_id  away_team_api_id
# 2488  2010-08-14 00:00:00        839796             10252              8654
# 2489  2010-08-14 00:00:00        839797              8655              8668
# 2490  2010-08-14 00:00:00        839799              8559              9879
# 2491  2010-08-14 00:00:00        839800              8455              8659
# 2494  2010-08-14 00:00:00        839803              8472              8658
# ...                   ...           ...               ...               ...
# 2803  2011-05-22 00:00:00        840230             10261              8659
# 2804  2011-05-22 00:00:00        840231              8602              8655
# 2805  2011-05-22 00:00:00        840232              9879              9825
# 2806  2011-05-22 00:00:00        840233              8559              8456
# 2807  2011-05-22 00:00:00        840234             10194              8528
#
# [380 rows x 4 columns]

# %%
highest_gap=pd.DataFrame(columns=["date","team"])
i=0
for _,x in clear_data.iterrows():
  highest_gap.loc[i]=[x.date,x.away_team_api_id]
  i=i+1
  highest_gap.loc[i]=[x.date,x.home_team_api_id]
  i=i+1
highest_gap
# Out:
#                     date   team
# 0    2010-08-14 00:00:00   8654
# 1    2010-08-14 00:00:00  10252
# 2    2010-08-14 00:00:00   8668
# 3    2010-08-14 00:00:00   8655
# 4    2010-08-14 00:00:00   9879
# ..                   ...    ...
# 755  2011-05-22 00:00:00   9879
# 756  2011-05-22 00:00:00   8456
# 757  2011-05-22 00:00:00   8559
# 758  2011-05-22 00:00:00   8528
# 759  2011-05-22 00:00:00  10194
#
# [760 rows x 2 columns]

# %%
highest_gap2=highest_gap.sort_values(['team','date'])\
                                     .reset_index(drop=True)

# %%
highest_gap2["date"]=pd.to_datetime(highest_gap2["date"])

# %%
highest_gap2["diffs"]=np.nan

# %%
highest_gap2
# Out:
#           date   team  diffs
# 0   2010-08-14   8455    NaN
# 1   2010-08-21   8455    NaN
# 2   2010-08-28   8455    NaN
# 3   2010-09-11   8455    NaN
# 4   2010-09-19   8455    NaN
# ..         ...    ...    ...
# 755 2011-04-23  10261    NaN
# 756 2011-05-01  10261    NaN
# 757 2011-05-07  10261    NaN
# 758 2011-05-15  10261    NaN
# 759 2011-05-22  10261    NaN
#
# [760 rows x 3 columns]

# %%
highest_gap2.set_index('team', inplace=True)

# %%
highest_gap2.sort_values(by=["team", "date"])
highest_gap2["diffs"]=highest_gap2["date"].diff()

# %%
highest_gap2["diffs"].max().days
# Out:
# 18

# %%
highest_gap_england_2010_2011 = highest_gap2["diffs"].max().days# Your code here

# %%
assert(isinstance(players_180_190, int))

assert(isinstance(players_1980, int))

assert(len(highest_players) == 10)
assert(isinstance(highest_players, list))
for i in range(10):
    assert(isinstance(highest_players[i], str))

assert(len(years_born_players) == 11)
assert(isinstance(years_born_players, list))
for i in range(10):
    assert(isinstance(years_born_players[i], tuple))
    assert(isinstance(years_born_players[i][0], int))
    assert(isinstance(years_born_players[i][1], int))



assert(isinstance(adriano_mean, float))
assert(isinstance(adriano_std, float))

assert(isinstance(dow_with_min_players_born, str))

assert(isinstance(league_most_matches, str))

assert(isinstance(max_matches_player, str))

assert(len(top_correlated_features) == 5)
assert(isinstance(top_correlated_features, list))
for i in range(5):
    assert(isinstance(top_correlated_features[i], tuple))
    assert(isinstance(top_correlated_features[i][0], str))
    assert(isinstance(top_correlated_features[i][1], str))


assert(len(neymar_similarities) == 5)
assert(isinstance(neymar_similarities, list))
for i in range(5):
    assert(isinstance(neymar_similarities[i], str))

assert(isinstance(borussia_bundesliga_2008_2009_matches, int))



assert(isinstance(team_most_matches_bundesliga_2008_2009, int))



assert(isinstance(arsenal_won_matches_2015_2016, int))



assert(isinstance(team_highest_winrate_2015_2016, str))


assert(isinstance(highest_gap_england_2010_2011, int))

# %% [markdown]
# ### Warning! Do not change anything in the area below

# %%
with open('student_answers.txt', 'w') as file:
    file.write(f"{players_180_190}\n")
    file.write(f"{players_1980}\n")
    file.write(f"{highest_players}\n")
    file.write(f"{years_born_players}\n")
    file.write(f"{round(adriano_mean, 3)} {round(adriano_std, 3)}\n")
    file.write(f"{dow_with_min_players_born}\n")
    file.write(f"{league_most_matches}\n")
    file.write(f"{max_matches_player}\n")
    file.write(f"{';'.join(['%s,%s' % tup for tup in top_correlated_features])};\n")
    file.write(f"{neymar_similarities}\n")
    file.write(f"{borussia_bundesliga_2008_2009_matches}\n")
    file.write(f"{team_most_matches_bundesliga_2008_2009}\n")
    file.write(f"{arsenal_won_matches_2015_2016}\n")
    file.write(f"{team_highest_winrate_2015_2016}\n")
    file.write(f"{highest_gap_england_2010_2011}\n")
